# %%
from sympy import *
from sympy.plotting import plot
from matplotlib import *
x=Symbol('x')
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
f1 = x**2 + 3*x - 4
f11 = 2*x + 3

# %%
solve_univariate_inequality(f11>0, x)
# Out:
# And(-3/2 < x, x < oo)

# %%
solve_univariate_inequality(f11<0, x)
# Out:
# And(-oo < x, x < -3/2)

# %% [markdown]
# x = -1.5
#
# y = -1.75
#
# (-1,5;-1,75) - min
#
# (-inf;-1.5) - убывает
#
# (-1.5,+inf) - возрастает

# %%
plot(f1)

# %%
f2 = x**3 - 2*x**2 + x - 6
f21 = 3*x**2 - 4*x + 1

# %%
solve_univariate_inequality(f21>0, x)
# Out:
# Or(And(-oo < x, x < 1/3), And(1 < x, x < oo))

# %%
solve_univariate_inequality(f21<0, x)
# Out:
# And(1/3 < x, x < 1)

# %% [markdown]
# x = {1/3,1}
#
# y = {-158/27, -6}
#
# (1/3;-158/27) - max
#
# (1;-6) - min
#
# (-inf;1/3) - возрастает
#
# (1/3;1) - убывает
#
# (1,+inf) - возрастает

# %%
plot(f2)

# %%
f3 =exp(2*x-x**2)
f31 = (2-2*x)*exp(2*x-x**2)

# %%
solve_univariate_inequality(f31>0, x)
# Out:
# And(-oo < x, x < 1)

# %%
solve_univariate_inequality(f31<0, x)
# Out:
# And(1 < x, x < oo)

# %% [markdown]
# x = 1
#
# y = e
#
# (1;e) - max
#
# (-inf;1) - возрастает
#
# (1,+inf) - убывает

# %%
plot(f3)
